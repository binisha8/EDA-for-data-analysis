# %% [markdown]
# ASTHAMA DISEASE DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filepath=r"C:\Users\ASUS\Downloads\asthma_disease_data.csv"
df=pd.read_csv(filepath,encoding='latin-1')

# %%
df.head()
# Out:
#    PatientID  Age  Gender  Ethnicity  EducationLevel        BMI  Smoking  \
# 0       5034   63       0          1               0  15.848744        0
# 1       5035   26       1          2               2  22.757042        0
# 2       5036   57       0          2               1  18.395396        0
# 3       5037   40       1          2               1  38.515278        0
# 4       5038   61       0          0               3  19.283802        0
#
#    PhysicalActivity  DietQuality  SleepQuality  ...  LungFunctionFEV1  \
# 0          0.894448     5.488696      8.701003  ...          1.369051
# 1          5.897329     6.341014      5.153966  ...          2.197767
# 2          6.739367     9.196237      6.840647  ...          1.698011
# 3          1.404503     5.826532      4.253036  ...          3.032037
# 4          4.604493     3.127048      9.625799  ...          3.470589
#
#    LungFunctionFVC  Wheezing  ShortnessOfBreath  ChestTightness  Coughing  \
# ...

# %% [markdown]
# COUNTPLOT

# %%
gender_mapping={0:'Female',1:'Male'}
df['gender_label']=df['Gender'].map(gender_mapping)
sns.countplot(data=df,x='Gender')
gender_counts = df['gender_label'].value_counts()
gender_counts.plot(kind='bar',rot=0,width=0.5)
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Histogram

# %%
plt.title("AGE DISTRIBUTION")
plt.hist(df['Age'],color="lightblue")
# Out:
# (array([258., 205., 276., 209., 234., 233., 221., 291., 215., 250.]),
#  array([ 5. , 12.4, 19.8, 27.2, 34.6, 42. , 49.4, 56.8, 64.2, 71.6, 79. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.title("Gender Distribution")

plt.pie(df['Gender'].value_counts(),autopct='%0.2f')

# %%
plt.title('Boxplot of Education Label')
sns.boxplot(df['EducationLevel'])
df.describe()
# Out:
#          PatientID          Age       Gender    Ethnicity  EducationLevel  \
# count  2392.000000  2392.000000  2392.000000  2392.000000     2392.000000
# mean   6229.500000    42.137960     0.493311     0.669732        1.307274
# std     690.655244    21.606655     0.500060     0.986120        0.898242
# min    5034.000000     5.000000     0.000000     0.000000        0.000000
# 25%    5631.750000    23.000000     0.000000     0.000000        1.000000
# 50%    6229.500000    42.000000     0.000000     0.000000        1.000000
# 75%    6827.250000    61.000000     1.000000     1.000000        2.000000
# max    7425.000000    79.000000     1.000000     3.000000        3.000000
#
#                BMI      Smoking  PhysicalActivity  DietQuality  SleepQuality  \
# count  2392.000000  2392.000000       2392.000000  2392.000000   2392.000000
# mean     27.244877     0.141722          5.051786     5.022867      7.019012
# ...

# %%
sns.lineplot(x='EducationLevel',y='Gender',data=df,c='#0f0',lw=1)
plt.title('LINEPLOT')
# Out:
# Text(0.5, 1.0, 'LINEPLOT')

# %%
sns.kdeplot(df['LungFunctionFVC'])
# Out:
# <Axes: xlabel='LungFunctionFVC', ylabel='Density'>

# %% [markdown]
# PairPlots

# %%
sns.barplot(x="Gender",y="EducationLevel",data=df,palette="Set2")
plt.title('Education Level by Gender')
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_2200\908414006.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Gender",y="EducationLevel",data=df,palette="Set2")
# Text(0.5, 1.0, 'Education Level by Gender')

# %%
sns.boxplot(x='Smoking', y='BMI', data=df, hue='Gender')
plt.xlabel('Smoking Status')
plt.ylabel('BMI')
plt.title('Boxplot of BMI by Smoking Status and Gender')
plt.show()

# %%
sns.scatterplot(x='Age', y='BMI', data=df)
plt.xlabel('Age')
plt.ylabel('BMI')
plt.title('Scatter Plot of Age vs. BMI')
plt.show()

# %%
sns.displot(df['LungFunctionFVC'])

# %%
sns.barplot(x='EducationLevel',y='Age',hue='Gender',data=df)
# Out:
# <Axes: xlabel='EducationLevel', ylabel='Age'>

# %%
sns.clustermap(df.pivot_table(values='EducationLevel',index='Gender',columns='Smoking'))

# %%
sns.heatmap(df.pivot_table(values='PhysicalActivity',index='Gender',column='SleepQuality'))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 1
# ----> 1 sns.heatmap(df.pivot_table(values='PhysicalActivity',index='Gender',column='SleepQuality'))
#
# TypeError: DataFrame.pivot_table() got an unexpected keyword argument 'column'
